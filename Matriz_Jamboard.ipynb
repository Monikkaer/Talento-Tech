# %% [markdown]
# <a href="https://colab.research.google.com/github/Monikkaer/Talento-Tech/blob/main/Matriz_Jamboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
# crear Dataframe de Pandas
data={
    'id':['1','2','3','4','5','5','6','7'],
    'weight':[144.5,167.2,124.1,144.5,133.2,133.2,124.1,129.2],
    'height':[5.9,5.4,5.2,5.9,5.7,5.7,5.2,5.3],
    'age':[33,45,23,33,54,54,23,42],
    'gender':['M','M','F','M','F','F','F','M']
}
df_persona = pd.DataFrame(data)
df_persona.head(10)
# Out:
#   id  weight  height  age gender
# 0  1   144.5     5.9   33      M
# 1  2   167.2     5.4   45      M
# 2  3   124.1     5.2   23      F
# 3  4   144.5     5.9   33      M
# 4  5   133.2     5.7   54      F
# 5  5   133.2     5.7   54      F
# 6  6   124.1     5.2   23      F
# 7  7   129.2     5.3   42      M

# %%
print(df.shape)
df.head()
# Out:
# (8, 5)
#   id  weight  height  age gender
# 0  1   144.5     5.9   33      M
# 1  2   167.2     5.4   45      M
# 2  3   124.1     5.2   23      F
# 3  4   144.5     5.9   33      M
# 4  5   133.2     5.7   54      F

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      8 non-null      object
#  1   weight  8 non-null      float64
#  2   height  8 non-null      float64
#  3   age     8 non-null      int64
#  4   gender  8 non-null      object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 448.0+ bytes

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      8 non-null      object
#  1   weight  8 non-null      float64
#  2   height  8 non-null      float64
#  3   age     8 non-null      int64
#  4   gender  8 non-null      object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 448.0+ bytes

# %%
  print(f'Tamaño del set antes de eliminar las filas repetidas:{df.shape}')
  df.drop_duplicates(inplace=True)
  print(f'Tamaño del set despues de eliminar las filas repetidas: {df.shape}')
# Out:
# Tamaño del set antes de eliminar las filas repetidas:(8, 5)
# Tamaño del set despues de eliminar las filas repetidas: (7, 5)

# %%
df.head()
# Out:
#   id  weight  height  age gender
# 0  1   144.5     5.9   33      M
# 1  2   167.2     5.4   45      M
# 2  3   124.1     5.2   23      F
# 3  4   144.5     5.9   33      M
# 4  5   133.2     5.7   54      F

# %%
df_peso = df['weight']/(0.908)
print(df_peso)
# Out:
# 0    159.140969
# 1    184.140969
# 2    136.674009
# 3    159.140969
# 4    146.696035
# 6    136.674009
# 7    142.290749
# Name: weight, dtype: float64
